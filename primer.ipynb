# %% [markdown]
# # A Brief Introduction to Using Jupyter Notebooks… Specifically, in Google Colaboratory

# %% [markdown]
# **Name(s):**
#
# 1.
#
# 2.

# %% [markdown]
# <br>
#
# ---
#
# Google Colaboratory (Colab) Notebooks are a form of Jupyter Notebook that allows you (and others!) to collaboratively edit and interact with the Notebook in the same way you can make shared edits on a Google Doc. The beauty of Jupyter Notebooks, however, is that it allows you to combine **computer code**, **mathematical equations in LaTeX**, and regular prose (words) in **Markdown** all in one interactive document. Colab notebooks are great because it provides the benefits of Jupyter notebooks without requiring students to install software on their own computers; rather, all of the code you run will be done in the Google Cloud. This means we don't have to worry about pesky installation issues, and everyone is on a level playing field. The same code will, in theory, run at the same speed whether you execute it from your phone or from a supercomputer.
#
# Jupyter notebooks in Python have the largest market share, but you can also run them using the R or Julia coding languages. For our class, we will use Jupyter notebooks in R. All three languages are in widespread use in Applied Statistics and Data Science. Note that R Jupyter notebooks aren't *officially* supported by Google Colab, but we can make them work.
#
# One big reason that Jupyter notebooks are used so widely in applied sciences is that they make it easy to develop mathematical models and software implementing these models, and *include explanations and derivations right in the same file*. This, along with the fact that you can export the notebook to a PDF (or other document formats), facilitates the sharing of research work. Being able to do this remotely is important (especially in the current pandemic situation), and being able to work with a lab partner (or *Colab* partner, if you will?! You won't? That's okay, I laughed) is just plain nice. It would be annoying to have to send codes to one another iteratively to work on something... and so enter Colab Jupyter notebooks.

# %% [markdown]
# <br>
#
# ---
#
# ## 1  Accessing and opening the Jupyter Notebook file
#
# **a)** To access Colab notebooks, go to https://colab.research.google.com/.
#
# **b)** From there, we can access the Jupyter notebook that I created this PDF tutorial from by pasting in the Github link. If you are unfamiliar with Github, just think of it as a big archive of different repositories of software. Each user can have their own set of repositories, and each repository is typically dedicated to a particular purpose. I set up a repository to house the Jupyter notebooks for this class. It's a great purpose.
#
# In the upper-left of your screen, you should see the `File` menu. Click it, and then click `Open notebook`.
#
# Click on the `Github` option on the horizontal menu along the top of the page that opens.
#
# Paste the Github URL for the `primer_r.ipynb` file on the search line next to the magnifying glass. This is URL for the Jupyter notebook we want to open, modify and run. The URL is:
# > https://github.com/tonyewong/math251/blob/master/primer_r.ipynb
#
# This will be different for each notebook. You can also preview the notebook in Github by clicking on the link above. There, the notebook will also include a button to `Open in Colab`.
#
# After you paste in the URL, press `Enter` or click on the magnifying glass search button. This should open a familiar-looking Jupyter notebook!
#
# **c)** While that was no doubt extremely exciting, you aren't quite there yet. If you aren't signed into a Google account, later, Colab will give you an error  message saying `Google sign-in required`. We can nip this in the bud by signing in first. In the upper-right, there should either be an icon showing your Google profile picture (or initials), or a blue button that says `Sign in`.
# * If it shows your Google profile picture (initials), then that's the Google Drive account that _*your*_ version of this Jupyter notebook will be saved under.
# * If the `Sign in` button is showing, then sign into your preferred Google Drive account (say, your RIT Google Drive?) by clicking the button and entering your RIT credentials. Keep in mind that the email address with be your RIT email address, followed by `@g.rit.edu` (note the "g.").
#
# **d)** Once you are signed in, try to save the notebook by either pressing `Ctrl+S` (or `Command+S` on a Mac) or clicking `File` > `Save`. You should get an error message that says "Cannot save changes. You do not have permission to save this notebook. To keep your changes, make a copy of the notebook." This message is telling you that I, the author of the notebook, don't want you messing around with my notebook! Fair enough. So, you need to click `Save a copy in Drive`. This will save a copy of the notebook in _your own_ Google Drive. Go ahead and click that now. Alternatively, you could have clicked `File` > `Save a copy in Drive` straightaway without that `Ctrl+S` nonsense.
#
# This will open a new window with a file entitled `Copy of primer_r.ipynb`. You can see this title at the top of your screen. This is _your version_ of the file, saved in *your* Google Drive as opposed to my Google Drive (where I made the file) or my Github repository (where I shared the file with you). Thus, we call your new version of the file your *local* version (since it is local to you). But, I'm sorry to say, the file's title sucks. Let's fix that. Click anywhere on the title and rename the file `[lastname1]_[lastname2]_primer_r.ipynb`, where the `lastname` fields are replaced by your and your lab partner's last names. So, for example, my file would be called `Wong_primer_r.ipynb` because nobody wants to be my lab partner.
#
# **e)** Finally, you are ready to get to work modifying and executing the codes in the Jupyter notebook! First, a helpful tidbit:
#
# To figure out _where_ in your Google Drive the file is located, click on `File` > `Locate in Drive`. This will open a window that highlights the Google Drive folder that is housing your notebook. Most often, new notebooks will be in a folder entitled `Colab Notebooks`. Feel free to create another Google Drive folder to put your lab notebooks in. How you organize your Google Drive is up to you, but I **strongly** encourage you to **back up your work** for this and all of your classes in Google Drive (or Github, or anywhere).

# %% [markdown]
# <br>
#
# ---
#
# ## 2  Code cells and Markdown cells
#
# Jupyter notebooks are made up of different "cells". Click once on this section of text. A box will appear around this text (and some areas above/below it) - all of that is within this cell. In the upper-right corner of the cell, you will see a horizontal menu with options to do various things with this cell, including move it up/down, edit it, add comments to it or delete it (among other things). Hover your cursor over each of the options to see what magic you can perform. Note that adding comments to the cell works analogously to adding comments to a Google Doc.
#
# There are two types of cells:  **Markdown** cells and **code** cells. Markdown is a kind of text formatting language that makes things look pretty when viewed in a web browser. You can also include adornments like hyperlinks, LaTeX equations, section headers and images.
#
# What you are looking at right now is the nicely-formatted Markdown text. To see the raw Markdown, do one of:
# * click on the `Edit` option in the menu of the cell you have selected,
# * press `Enter` while that cell is selected, or
# * double-click on that cell.
#
# A couple of the features you will see in this Markdown cell:
# * The `<br>` command adds a vertical space to your notebook. This is nice for separating sections.
# * The `---` command creates a horizontal line. This is also nice for separating sections.
# * The `#` sign is used to create a new section header; two `#` signs (`##`) is used to create a new subsection header; `###` creates a subsubsection; more than that and you're just showing off.
# * You can create a bulleted list by using the asterisk `*` and a space.
# * You can create regular text by just typing as usual.
# * You can create bold-faced text by wrapping it with two asterisks on either side (see the words "Markdown" and "code" above).
# * To create a new paragraph, you must include a blank line between the old and new paragraphs.
#
# At this point you might be wondering how to turn this cell back into the fully formatted Markdown text instead of the raw Markdown you're probably still looking at. In Colab, you have two options:
# 1. Press `Shift+Enter` to *execute* the cell.
# 1. Click the `Close Markdown editor` button in the cell menu in the upper-right.

# %% [markdown]
# ### Question:
# How do you create *italicized* words? Type your answer below this cell by clicking on this cell, then clicking the `+ Text` button above. This will add a new Markdown text cell below the current one. Colab will automatically enter you into "Edit" mode in the new cell. Then, you can type in your answer and *execute* the cell as described above to format your answer as nice text. For the lab exercises, please always place your answers in their own cell. Typically, I will provide empty cells where answers should go.

# %% [markdown]
# ### Question:
# Is there _more_ than one way to create italicized words? If you hover your cursor just below this Markdown cell, the options to add a code cell or add a text cell should appear. For this, and the rest of the Questions, add cells as needed to supply your answers.

# %% [markdown]
# ### Question:
# How can you create a numbered list? Is there anything remarkable about the way a numbered list is created?

# %% [markdown]
# ### Question:
#
# What does putting a "`" around a word do? That's the symbol just to the left of the 1 key. You may want to re-examine the raw Markdown from the first cell of Section 2.

# %% [markdown]
# <br>
#
# ---
#
# ## 3  Basic mathematical operations
#
# Now arguably the most important part of the whole computer coding part of this course is to perform mathematical operations. It begins by defining **variables**, which work the same way as defining a variable in regular paper-and-pencil mathematics. In R, the "arrow" `<-` takes the place of an equals sign to assign a value to a variable. So, for example, if we would like to declare that the variable `x` is equal to 6, we can say:
#
# ```
# x <- 6
# ```
#
# To actually enter that into the computer, you need to use the second kind of Jupyter notebook cell, a **code cell**. You can place one just below your currently selected cell by clicking `+ Code` in the upper-left, or by hovering your cursor at the bottom of this cell and then clicking `+ Code`. For convenience, a code cell is included below with the code to set a variable named `x` equal to 6. To *execute* that code cell, select the cell by clicking on it; the thin box should surround the cell. Then, hit `Shift+Enter`.

# %%
x <- 6

# %% [markdown]
# After you have executed the above cell, we can check to see what value the variable `x` has in the computer's memory by asking R to print `x` to the screen. We use a **function** called (appropriately enough) `print()` to do this. Inside the parentheses, we place the **argument** of the function. In mathy terms, we call this the **input** to the function. In this case, the argument (input) should be `x`, since that's the thing we want to be printed. Execute the code cell below to run the `print()` function for the input variable `x`.

# %%
print(x)

# %% [markdown]
# Armed with our knowledge of how to define a variable, we can do all kinds of mathematical operatinos to these variables. For example, to add 4 to `x`, we can do exactly what you would think you should do:

# %%
x + 4

# %% [markdown]
# We can define a new variable, `y`, whose value is the value of `x` plus 4 as follows. Note that you can execute multiple commands within a single code cell by putting a new command on a new line (using the `Enter` key to create new lines). For example:

# %%
y <- x + 4   # create a variable called y and assign it the value x+4
print(y)     # print y to the screen

# %% [markdown]
# Now let's say we want to change `x` to be equal to 8.
#
# ### Question:
#
# In the code cell below, write code to make this change and execute it. (okay, this isn't really a "question"...)

# %% [markdown]
# ### Question:
#
# What do you reckon has happened to the value of `y`? Does it stay at 10, or does it change to 12 because it is equal to `x+4`? In the code cell below, print `y` to the screen to find out!

# %% [markdown]
# Let's say we want to add 4 to `y`, then divide by 2. But we want to perform the addition operation first. We can do this the same way we would force that when writing a mathematical expression: by using parentheses to override the normal order of operations. We can even "reset" the value of `y` so that its new value is equal to the old value plus 4, then divided by 2:

# %%
y <- (y + 4)/2
print(y)

# %% [markdown]
# What about slightly fancier mathematical operations? Suppose we want to raise Euler's constant, $e$, to the 3rd power?  That is, how can we calculate $e^3$?
#
# First, an important notational convenience is that we frequently use the `exp()` function to denote raising $e$ to whatever power is inside the parentheses in `exp()`. So, $e^3$ = `exp(3)`.

# %%
exp(3)

# %% [markdown]
# **Sanity Check:**  I love sanity checks. There's a great way to make sure your answers make sense, which catches something like 73% of mathematical errors. Okay, yes, I made that up. But sanity checks are very useful.
#
# We can perform a quick sanity check on our answer for $e^3$ above by considering 3 basic facts:
# * $e \approx 2.7$
# * $2^3 = 8$
# * $3^3 = 27$
#
# So, since $e$ is between 2 and 3, we know that $e^3$ should be somewhere between $2^3$ and $3^3$. Since our answer of about 20.1 is safely between 8 and 27, we are in good shape, and do not have reason to believe we are insane. Very nice!
#
# **Upshot:** When doing your work, always be thinking about ways you can apply sanity checks to make sure your answers and intermediate steps all make sense.
#
# **And also** note that this is by no means a complete guide to all the great mathematics you can do in R! Google is your friend. If you are curious how to take the cosine of something in R, for example, you can search for "cosine r" and a top hit will return the following page, among other useful links:
#
# https://stat.ethz.ch/R-manual/R-devel/library/base/html/Trig.html
#
# Don't be afraid to search the internet for tips on how to code things you don't know. Nobody knows everything! I still Google for how to do stuff in R all the time.

# %% [markdown]
# <br>
#
# ---
#
# ## 4 A little bit fancier mathematical operations
#
# Suppose we measure the maximum monthly temperature (in degrees Fahrenheit) in a city throughout a year and obtain the following _array_ of data:
#
# ```
# [39, 45, 54, 66, 72, 89, 94, 90, 81, 79, 57, 41]
# ```
#
# That is, the maximum temperature in January was 39 $^\circ$F, the maximum temperature in February was 45 $^\circ$F, and so on. How can we represent this set of data in R?
#
# Well, for me, when I Googled "array in R" one of the first results was this:
#
# https://www.tutorialspoint.com/r/r_arrays.htm
#
# That tutorial points to the simplest way to create an array (or a set of related variables) in R, which is with the `c()` function. The argument of this function is a list of the values you want in the array, separated by commas. To set a variable called `temps` to this array, we can do the following:

# %%
temps <- c(39, 45, 54, 66, 72, 89, 94, 90, 81, 79, 57, 41)

# %% [markdown]
# Let's print `temps` to the screen to check that it has the right numbers, and all of the numbers, stored in it.

# %%
print(temps)

# %% [markdown]
# Great! It looks like things are working well.
#
# Are you wondering why the heck the function to create an array out of a set of numbers is called "c"? Why the letter c? This is a reference to the fact that the `c()` function in R is a generic function to _combine_ its arguments, or _concatenate_ them. How cool, right? Tell your friends!
#
# <br>
#
# Now, how do we access each element of the array individually? If someone asks us what the maximum temperature in January was, how do we obtain that from our variable `temps`?
#
# We can access the $i$th value in `temps` by **indexing** within the array. That is, in math-speak, $\texttt{temps}_i$ (with the subscript $i$) typically refers to the $i$th element within the array `temps`. In R, we grab the $i$th element by following the array name with square brackets:  `temps[i]`. Since January is the first, or $i=1$, element within `temps`, we do `temps[1]`:

# %%
print(temps[1])

# %% [markdown]
# ### Question:
#
# What is the maximum temperature for June? Print this element from `temps` to the screen.

# %% [markdown]
# ### Question:
#
# What is the average of the maximum temperatures from June and July? (The _average_ of a set of numbers is their sum, divided by the number of terms in the set.)

# %% [markdown]
# We can also do things like create a plot of the temperatures.

# %%
plot(temps)

# %% [markdown]
# That's nice and all, but it lacks a critical aspect of a nice plot: axis labels! We can use the `plot()` function's *optional arguments* for `xlab` and `ylab` to provide names for the x-axis label and y-axis label, respectively. These arguments are a type of variable called a **string**, which is a fancy way to say that they're words (or more specifically, a set of characters _strung_ together). We denote string variables by wrapping them in quotation marks "_string characters here_")

# %%
plot(temps, xlab="month", ylab="degrees Fahrenheit")

# %% [markdown]
# Ah. Much better. There are loads of other ways you can customize a plot in R. For example, to connect these dots and plot the temperatures as a _line_, we would use the `type` argument of `plot()`:

# %%
plot(temps, xlab="month", ylab="degrees Fahrenheit", type="l")

# %% [markdown]
# The `type` argument can have a variety of different values. Here, we are using `type="l"` to create a line plot (the "`l`" stands for "line").
#
# ### Question:
#
# Using the internet to find help, see if you can figure out what the value of `type` should be to include _both_ points (like our original plot) and these lines.

# %% [markdown]
# ## 5 Formatting mathematical expresssions
#
# You may have noticed back in [Section 3](https://colab.research.google.com/drive/1wTcPaNt38RBViv6UxeH-053QxZdigY_I?authuser=1#scrollTo=IwGFMNPBX23-&line=3&uniqifier=1) we had a mathematical expression that looked a bit different from its surrounding text: $e^3$. That's because this expression was formatted using LaTeX (pronounced lay-tek or lah-tek). Well, to be specific, it was formatted using MathJax, which is a way to format bits of LaTeX code, whereas LaTeX is a full document-formatting language.
#
# The basic idea is that we can wrap mathematical expressions with dollar signs (`$`*expression*`$`) in order to have it formatted all pretty-like. That way, we can show things like exponents, subscripts, summations (those sigma beasts that haunt your dreams from Calculus 2?), integrals, fractions, and so forth. You can see the code in this cell for the exponential expression $e^3$ by selecting this cell (click on it once) and then entering "edit" mode (double-click on it, or click the `Edit` icon in the menu in the upper-right, or press `Enter`).

# %% [markdown]
# ### Question:
#
# Create a Markdown cell below and in it, place the Pythagorean Theorem (illustrated below).
#
# <img src="https://miro.medium.com/max/923/1*SsN2DG__Z5DyOI0uf7hbwQ.png" width=300px>

# %% [markdown]
# We can include more complex expression in exponents by wrapping them with curly brackets `{`*expression*`}`. For example, later in the semester, we will find that the *exponential distribution function*, $f(x) = \lambda e^{-\lambda x}$, is important and useful.
#
# Wait a second! How the heck did you type that Greek letter $\lambda$? Ah! There it is again!
#
# Greek and other special symbols in LaTeX can be accessed by preceding a "code" for that character with a backslash `\`. Double-click on this cell to see how to format a $\lambda$, and how the curly brackets work.

# %% [markdown]
# ### Question:
#
# How do you think you can format an "alpha"? Create a Markdown cell below and give it a shot!

# %% [markdown]
# If you aren't sure how to format a special character in LaTeX, Google is probably your first stop. A super handy tool, called "Detexify", is available here:
#
# https://detexify.kirelabs.org/classify.html
#
# This tool allows you to draw the symbol you want, and will suggest some LaTeX commands that might create that symbol.
#
# We don't have time to go through every last LaTeX command you might want to use in Jupyter notebooks, but a much more complete primer for MathJax/LaTeX formatting in Jupyter notebooks is available here:
#
# https://math.meta.stackexchange.com/questions/5020/mathjax-basic-tutorial-and-quick-reference
#
# Use this, and the internet, as a reference when you encounter some kind of formatting that you aren't sure how to do. Most things with LaTeX and Jupyter will be learned on the fly because beforehand, it's hard to even know what questions to ask or skills to try to learn! This tutorial is already long enough; I don't want you to spend hours and hours going through an even longer tutorial that includes too many topics you'll never use. It's through applications that we will see throughout the semester that we can focus on the techniques and skills that are truly useful.

# %% [markdown]
# <br>
#
# ---
#
# ## 6 Embedding images
#
# As you may have noticed from the [image of the Pythagorean Theorem in action](https://colab.research.google.com/drive/1wTcPaNt38RBViv6UxeH-053QxZdigY_I?authuser=1#scrollTo=JKjiMrP2UFbe&line=1&uniqifier=1), we can also include images in our Jupyter notebooks.
#
# The formatting for the Pythagorean Theorem image was a bit fancier, which we will explain in a moment, but the general syntax for including images (jpg or png file types work easily) is as follows:
#
# `![alt text](file path to image)`
#
# So to include an image file called `cactus.png` that is in a folder called `figs`, which is in the same directory as the Jupyter notebook I'm working in, I would use the following code.
#
# `![this is a cactus](./figs/cactus.png)`
#
# Note that this must be done in a **Markdown cell**, not a code cell. To change cell types, click on the `Tools` menu at the top of the page, then select `Command palette`. This will open a menu of different options. If you have a Markdown cell selected, you will have the option to `Convert to a code cell`. Conversely, if you have a code cell selected, you will have the option to `Convert to a text cell`.

# %% [markdown]
# The need for the local file path poses a problem when you share notebooks with others (say, your lab partner, or instrutor) because you only really want to share your ipynb Jupyter notebook file. You don't want to need to keep track of all kinds of auxiliary files for images to embed because that would be very annoying.
#
# Instead, we can be slick!
#
# We can include images via an internet URL by replacing the local file path in parentheses above with a URL. You can get image URLs by right-clicking on an image and clicking "Copy image address". If you have your images on a server somewhere, great. If not, have no fear, as with many aspects of life, Google Drive is here to help.
#
# You can get share links for items in your Google Drive in the usual way (right click, Get shareable link). If you go this route, be sure to change the settings so that *anyone* with the link can view, not just people at RIT.
#
# Now, simply replacing the URL or local file path with the Google share link will **not** work. Suppose that for an image I want to embed in this Jupyter notebook, the full share link as copied out of Google Drive is [https://drive.google.com/file/d/1iy4EQQZy0jfhYlHDys1uQAS5wf2hXGmZ/view?usp=sharing](https://drive.google.com/file/d/1iy4EQQZy0jfhYlHDys1uQAS5wf2hXGmZ/view?usp=sharing).
#
# I can include this image by taking the *file ID* of this file, prepending it with `https://docs.google.com/uc?export=download&id=`, and inserting *that* string within the parentheses for the image file. The file ID is the string of characters between the forward slashes after the `/d/` in the share link.  So, the file ID for my image is the string `1iy4EQQZy0jfhYlHDys1uQAS5wf2hXGmZ`.
#
# To include the image, I would use the syntax below. Double click on the image itself to see this in action.
#
# `![strange planet](https://docs.google.com/uc?export=download&id=1iy4EQQZy0jfhYlHDys1uQAS5wf2hXGmZ)`
#
# ![strange planet](https://docs.google.com/uc?export=download&id=1iy4EQQZy0jfhYlHDys1uQAS5wf2hXGmZ)

# %% [markdown]
# "Damn!" You might say, "That is a really large image! Is there some way to adjust the size?"
#
# What a good question you have asked! There is.
#
# We can use HTML code within Jupyter notebooks in order to have more control over the formatting of both images and text. To adjust the image to have a width of 500 pixels, we can use the HTML `img` command as shown below. Note that the URL used is the same as with the Markdown `![]()` syntax. Double click on this cell to verify that this is not deception.
#
# `<img src="https://docs.google.com/uc?export=download&id=1iy4EQQZy0jfhYlHDys1uQAS5wf2hXGmZ" width="500px"/>`
#
# <img src="https://docs.google.com/uc?export=download&id=1iy4EQQZy0jfhYlHDys1uQAS5wf2hXGmZ" width="500px"/>

# %% [markdown]
# ## 7 Assorted tips
#
# * On the left, you will see a vertical menu with three options. The top option will show you a Table of contents for the Jupyter notebook. This will present the notebook title and (sub)section headers. You can click on these to jump to those (sub)sections. When you create your own Jupyter notebooks, this is a handy way to organize your work.
# * Click the X in the upper-right of the left-hand menu to close it and reclaim a larger portion of your screen for your glorious notebook.
# * Just like with Google Docs, your changes are *generally* all saved. You can view these waypoints and changes by clicking `File` > `Revision history`.
# * Note, however, that the frequency with which Google auto-saves the notebook might not match how often _you_ want to save your work (say, after you complete a tough section). Also, it is always good to manually save every once in a while to make sure (1) you're still connected to your Google Drive and (2) you're still connected to the internet. It doesn't happen often, but if it does and you lose a bunch of work, that's a very frustrating experience.

# %% [markdown]
# ## 8 So what do I do with these coding labs?
#
# Now there's a good question!
#
# These labs are meant to introduce how the concepts we learn in the classroom play out in real-world coding and data-driven applications. You will notice that there are a number **Question:** subsubsection labels peppered throughout the notebook. I format them as subsubsections so that you'll see where they all are in the Table of contents (see [Section 7](https://colab.research.google.com/drive/1wTcPaNt38RBViv6UxeH-053QxZdigY_I?authuser=1#scrollTo=6F-TxAkzfy5m&line=6&uniqifier=1) above). Your job is to make sure you answer all of these questions, then hand in your Jupyter notebook. Easy as that!
#
# Some finer details:
# * Show any/all relevant work.
# * Put you and your lab partner's names at the top of the notebook.
# * Change the notebook title as described in [Section 1d](https://colab.research.google.com/drive/1wTcPaNt38RBViv6UxeH-053QxZdigY_I?authuser=1#scrollTo=5DcDLCzGcjTN&line=2&uniqifier=1), so it includes both of your last names.
# * To download the Jupyter notebook as an "ipynb" file (the normal Jupyter notebook file extension), click on `File` > `Download .ipynb`.
# * You can also download the file as a PDF by clicking `File` > `Print` and then selecting `Save as PDF` (this may differ depending on whether you're using a Windows/Mac/Linux computer). While PDF files make it easy to share and view other Jupyter notebooks, frequently, Jupyter notebooks have a bit of trouble exporting to a PDF file and end up losing some sections or formatting some poorly. When it works, it's great, but just so you're warned...
